# %%
# Code implementation block
# !wget https://efrosgans.eecs.berkeley.edu/cyclegan/datasets/monet2photo.zip
# !unzip monet2photo.zip
#"downloaded and extracted the monet2photo dataset, which provides unpaired
#images from two domains — Monet-style paintings and real-world photographs. These are used to train and test the CycleGAN model."
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: monet2photo/trainB/2016-03-31 05:58:36.jpg
#   inflating: monet2photo/trainB/2014-01-10 12:46:39.jpg
#   inflating: monet2photo/trainB/2015-02-23 11:45:00.jpg
#   inflating: monet2photo/trainB/2015-05-23 09:38:08.jpg
#   inflating: monet2photo/trainB/2016-01-15 00:48:49.jpg
#   inflating: monet2photo/trainB/2016-12-27 18:15:26.jpg
#   inflating: monet2photo/trainB/2017-01-02 11:16:05.jpg
#   inflating: monet2photo/trainB/2015-08-06 11:08:32.jpg
#   inflating: monet2photo/trainB/2015-12-16 07:43:36.jpg
#   inflating: monet2photo/trainB/2016-03-25 12:57:28.jpg
#   inflating: monet2photo/trainB/2016-05-10 11:44:44.jpg
#   inflating: monet2photo/trainB/2015-03-11 08:01:52.jpg
#   inflating: monet2photo/trainB/2015-08-30 05:26:05.jpg
#   inflating: monet2photo/trainB/2015-10-03 19:00:56.jpg
#   inflating: monet2photo/trainB/2016-06-08 02:40:47.jpg
#   inflating: monet2photo/trainB/2016-02-28 23:11:19.jpg
# ...

# %%
# Code implementation block
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# %cd pytorch-CycleGAN-and-pix2pix
#This changes current working directory to the newly downloaded folder.
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2516, done.
# remote: Total 2516 (delta 0), reused 0 (delta 0), pack-reused 2516 (from 1)
# Receiving objects: 100% (2516/2516), 8.20 MiB | 38.17 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# Code implementation block
# %pip install -r requirements.txt
# %pip install dominate visdom
#"installed all necessary dependencies listed in the official requirements file, including PyTorch, torchvision, and other supporting libraries."
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.9 MB/s eta 0:00:00
# ...

# %%
# Code implementation block
# !mkdir -p datasets/monet2photo
# !cp -r /content/monet2photo/* datasets/monet2photo/
#organized the dataset into the expected folder structure required by CycleGAN by creating the datasets/monet2photo directory and copying our data into it."

# %%
# Code implementation block
# !ls datasets/monet2photo
# Out:
# testA  testB  trainA  trainB

# %%
# Code implementation block
# !bash ./scripts/download_cyclegan_model.sh monet2photo #that downloads a pretrained model for the monet2photo task.
# !python test.py --dataroot ./datasets/monet2photo --name monet2photo_pretrained --model test --no_dropout
#tested the pretrained model on real-world photos. The output images, saved in the results folder, s
#how realistic Monet-style artwork generated using the CycleGAN."
# Out:
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [monet2photo]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2025-06-30 18:42:58--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/monet2photo.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45575747 (43M)
# Saving to: ‘./checkpoints/monet2photo_pretrained/latest_net_G.pth’
#
# ./checkpoints/monet 100%[===================>]  43.46M  59.7MB/s    in 0.7s
#
# ...

# %%
# Code implementation block
import os
from IPython.display import Image, display

result_dir = './results/monet2photo_pretrained/test_latest/images'
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, axs = plt.subplots(4, 5, figsize=(15, 10))  # 4 rows, 5 columns
axs = axs.flatten()

#display the generated Monet-style images in a 4x5 grid. It loads the first 20 fake images from the results folder


for i, img_file in enumerate(fake_images[:20]):
    img_path = os.path.join(result_dir, img_file)
    img = mpimg.imread(img_path)
    axs[i].imshow(img)
    axs[i].axis('off')
    axs[i].set_title(img_file, fontsize=8)

plt.tight_layout()
plt.show()

# %%
# Code implementation block

# %% [markdown]
# ---
#
# ## Part 2: Neural Style Transfer (Picasso-styled Mona Lisa)
#
# This section implements Neural Style Transfer to apply the artistic style of Pablo Picasso to Leonardo da Vinci's Mona Lisa. We will use a pre-trained VGG19 network to extract content and style features, and optimize a target image to match both.

# %%
# Code implementation block
import torch
import torch.nn as nn
import torch.optim as optim
from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms as T
import torchvision.models as models
import requests
from io import BytesIO
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

def load_image(url, max_size=400, shape=None):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}
    response = requests.get(url, headers=headers)
    image = Image.open(BytesIO(response.content)).convert('RGB')
    
    if max(image.size) > max_size:
        size = max_size
    else:
        size = max(image.size)
    
    if shape is not None:
        size = shape
        
    in_transform = T.Compose([
                        T.Resize(size),
                        T.ToTensor(),
                        T.Normalize((0.485, 0.456, 0.406), 
                                    (0.229, 0.224, 0.225))])
    
    image = in_transform(image)[:3,:,:].unsqueeze(0)
    return image.to(device)

def im_convert(tensor):
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    image = image.clip(0, 1)
    return image

content_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg/400px-Mona_Lisa%2C_by_Leonardo_da_Vinci%2C_from_C2RMF_retouched.jpg"
content_img = load_image(content_url).to(device)

style_url = "https://upload.wikimedia.org/wikipedia/en/1/14/Picasso_The_Weeping_Woman_Tate_identifier_T05010_10.jpg"
style_img = load_image(style_url, shape=content_img.shape[-2:]).to(device)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.imshow(im_convert(content_img))
ax1.set_title("Content: Mona Lisa")
ax2.imshow(im_convert(style_img))
ax2.set_title("Style: Picasso")
plt.show()

# %%
# Code implementation block
# Load VGG19 model and freeze parameters
# We use torchvision.models.vgg19(weights='DEFAULT') or pretrained=True depending on torchvision version
try:
    vgg = models.vgg19(weights=models.VGG19_Weights.DEFAULT).features
except:
    vgg = models.vgg19(pretrained=True).features

for param in vgg.parameters():
    param.requires_grad_(False)
vgg.to(device)

def get_features(image, model, layers=None):
    if layers is None:
        layers = {'0': 'conv1_1', '5': 'conv2_1', 
                  '10': 'conv3_1', '19': 'conv4_1', 
                  '21': 'conv4_2',  # content representation
                  '28': 'conv5_1'}
    features = {}
    x = image
    for name, layer in model._modules.items():
        x = layer(x)
        if name in layers:
            features[layers[name]] = x
    return features

def gram_matrix(tensor):
    _, d, h, w = tensor.size()
    tensor = tensor.view(d, h * w)
    gram = torch.mm(tensor, tensor.t())
    return gram

content_features = get_features(content_img, vgg)
style_features = get_features(style_img, vgg)

style_grams = {layer: gram_matrix(style_features[layer]) for layer in style_features}

# Create a target image to optimize (start with content image)
target = content_img.clone().requires_grad_(True).to(device)

# %%
# Code implementation block
# Weights for layers
style_weights = {'conv1_1': 1., 'conv2_1': 0.75, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
content_weight = 1  # alpha
style_weight = 1e6  # beta

optimizer = optim.Adam([target], lr=0.003)
steps = 2000

for i in range(1, steps+1):
    target_features = get_features(target, vgg)
    content_loss = torch.mean((target_features['conv4_2'] - content_features['conv4_2'])**2)
    
    style_loss = 0
    for layer in style_weights:
        target_feature = target_features[layer]
        target_gram = gram_matrix(target_feature)
        _, d, h, w = target_feature.shape
        style_gram = style_grams[layer]
        layer_style_loss = style_weights[layer] * torch.mean((target_gram - style_gram)**2)
        style_loss += layer_style_loss / (d * h * w)
        
    total_loss = content_weight * content_loss + style_weight * style_loss
    
    optimizer.zero_grad()
    total_loss.backward()
    optimizer.step()
    
    if  i % 400 == 0:
        print('Total loss: ', total_loss.item())

# Final Plot
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
ax1.imshow(im_convert(content_img))
ax1.set_title("Content Image")
ax2.imshow(im_convert(style_img))
ax2.set_title("Style Image")
ax3.imshow(im_convert(target))
ax3.set_title("Target Image")
plt.show()
